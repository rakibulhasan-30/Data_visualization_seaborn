# %% [markdown]
# # 02: Line Charts
#
# This notebook demonstrates **line charts** using Seaborn to visualize trends in Spotify streaming data.
# We will plot daily global streams of popular songs in 2017-2018.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# **Libraries Used:**
# - `pandas` for data manipulation
# - `matplotlib` and `%matplotlib inline` for plotting
# - `seaborn` for advanced visualizations

# %%
spotify_data = pd.read_csv("spotify.csv", index_col="Date", parse_dates=True)
spotify_data.head()
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %% [markdown]
# We load the Spotify dataset using `pandas.read_csv()` with the **Date** column as the index.
# `parse_dates=True` ensures dates are recognized as datetime objects.

# %%
plt.figure(figsize=(16,10))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify_data)
# Out:
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %% [markdown]
# Here we plot the daily streams of all songs to observe overall trends and patterns.
# The figure size is set large for better readability.

# %%
plt.figure(figsize=(16,10))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# We focus on two popular songs: **Shape of You** and **Despacito**.
# This allows a clear comparison of their streaming trends over time.

# %% [markdown]
# ## Observations / Results
#
# - "Shape of You" shows a consistent high number of streams throughout the period, peaking at certain events.
# - "Despacito" has a sharp rise in streams after its release and then gradually stabilizes.
# - Line charts help identify trends, peaks, and patterns in song popularity over time.
# - Comparing multiple songs in one plot makes it easier to see which song had higher streams on specific dates.
